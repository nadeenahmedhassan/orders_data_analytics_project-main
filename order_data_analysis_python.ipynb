# %%
# !pip install kaggle
# Out:
# ...
#      ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/82.7 kB ? eta -:--:--
#      --------- ---------------------------- 20.5/82.7 kB 330.3 kB/s eta 0:00:01
#      ----------------------- -------------- 51.2/82.7 kB 375.8 kB/s eta 0:00:01
#      -------------------------------------- 82.7/82.7 kB 421.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105796 sha256=62795fd590dd8c3a003c6f0e64dc5fc5f60874cebc819b35936a71d3e95ec09a
#   Stored in directory: c:\users\ncm\appdata\local\pip\cache\wheels\ff\55\fb\b27a466be754d2a06ffe0e37b248d844f090a63b51becea85d
# Successfully built kaggle
# ...

# %%
import kaggle

# %%
# !kaggle datasets download -d ankitbansal06/retail-orders
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# retail-orders.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

# %%
#extract file from zip file
import zipfile
zip_ref=zipfile.ZipFile('retail-orders.zip')
zip_ref.extractall() #extract file to dir
zip_ref.close() #close file

# %%
import pandas as pd
df=pd.read_csv('retail-orders.zip',na_values=['Not Available','unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
#rename columns names ..make them lower case and replace space with underscore
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
#derive new columns discount , sale price and profit
df["discount"]=df['list_price']*df['discount_percent']*.01
df.head()

# %%
df['sale price']=df['list_price']-df['discount']
df.head()

# %%
#profit
df['profit']=df['sale price']-df['cost_price']
df.head()

# %%
#convert order date from object data type to datetime
df['order_date']=pd.to_datetime(df['order_date'],format="%Y-%m-%d")
df.head()

# %%
#drop cost price list price and discount percent columns
df.drop(columns=['cost_price','list_price','discount_percent'],inplace=True)
df.head()

# %%
import sqlalchemy as sa

# Define the connection string
connection_string = (
    "mssql+pyodbc://DESKTOP-UI9FGDF/master?"
    "driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# Create an engine
engine = sa.create_engine(connection_string)
conn=engine.connect()
# Test the connection

#try:
#    with engine.connect() as conn:
#        print("Connection successful!")
#except Exception as e:
#    print(f"Error connecting to the database: {e}")

# %%
df.to_sql('orders', con=conn , index=False, if_exists = 'append')

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'sale price', 'profit'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 16

# %%
df.dtypes
# Out:
# order_id                 int64
# order_date      datetime64[ns]
# ship_mode               object
# segment                 object
# country                 object
# city                    object
# state                   object
# postal_code              int64
# region                  object
# category                object
# sub_category            object
# product_id              object
# quantity                 int64
# discount               float64
# sale price             float64
# profit                 float64
# dtype: object

# %%
df['postal_code'].astype(str).str.len().max()
# Out:
# 5

# %%
df['region'].str.len().max()
# Out:
# 7

# %%
df['category'].str.len().max()
# Out:
# 15

# %%
df['quantity'].max()
# Out:
# 14

# %%
df['discount'].max()
# Out:
# 905.6

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...
